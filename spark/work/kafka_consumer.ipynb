# %%
from confluent_kafka import Consumer
from time import sleep

broker = "kafka-broker:9092"
topic = "dvdrental.public.city"
group_id = "python"

# %%
consumer_config = {
    'bootstrap.servers': broker,
    'group.id': group_id,
    'auto.offset.reset': 'earliest',
    'enable.auto.commit': 'false',
    'max.poll.interval.ms': '86400000'
}

consumer = Consumer(consumer_config)
consumer.subscribe([topic])

# %%
try:
    while True:
        print("Listening")
        # read single message at a time
        msg = consumer.poll(0)
        
        if msg is None:
            sleep(5)
            continue
        if msg.error():
            print("Error reading message : {}".format(msg.error()))
            continue
        # You can parse message and save to data base here
        print(msg.offset())
        print(msg.topic())
        print(msg.value())
        
        consumer.commit()

except Exception as ex:
    print("Kafka Exception : {}", ex)

finally:
    print("closing consumer")
    consumer.close()

#RUNNING CONSUMER FOR READING MESSAGE FROM THE KAFKA TOPIC
#my_consumer = ExampleConsumer()
#my_consumer.start_listener()
# Out:
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# 604
# dvdrental.public.city
# b'{"city_id":605,"city":"RIBS","country_id":15,"last_update":1675692331569106}'
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# 605
# dvdrental.public.city
# b'{"city_id":605,"city":"Ribeir\xc3\xa3o","country_id":15,"last_update":1675692373405478}'
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# Listening
# closing consumer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 8
#       5 msg = consumer.poll(0)
#       7 if msg is None:
# ----> 8     sleep(5)
#       9     continue
#      10 if msg.error():
#
# KeyboardInterrupt:
